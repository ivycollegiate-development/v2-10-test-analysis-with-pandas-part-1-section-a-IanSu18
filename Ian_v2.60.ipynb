# %%
# Core data manipulation libraries
import pandas as pd # For working with DataFrames
import numpy as np # For numerical operations
# Machine learning tools from scikit-learn
from sklearn.model
_
selection import train
test
_
_
split # For creating
training/testing datasets
from sklearn.linear
_
model import LinearRegression # Our basic prediction
algorithm
from sklearn.metrics import mean
_
squared
_
error, r2
_
score # For evaluating
model performance
# Visualization
import matplotlib.pyplot as plt import seaborn as sns # For creating plots
# For enhanced visualizations
# Load the dataset
df = pd.read
_
csv('Pandas
Lesson
_
_
Grades.csv')
print(f"Loaded dataset with {df.shape[0]} rows and {df.shape[1]} columns")
2. Prepare numerical features for modeling:
# Convert percentage strings to floats
# This removes the '%' symbol and converts to numeric values
df['% Correct'] = df['% Correct'].str.rstrip('%').astype(float)
# Let's examine the 'Responses' column to understand its structure
print("Example 'Responses' values:")
print(df['Responses'].head(3))
# This helper function extracts features from the response patterns
# It's provided for you - review it to understand what it does
def extract
_
response
_
features(response
_
str):
"""
Extracts numerical features from response pattern strings like "A:69%
B:23% C:8%"
Parameters:
response
_
str (str): The response pattern string
Returns:
dict: Dictionary containing extracted features
"""
